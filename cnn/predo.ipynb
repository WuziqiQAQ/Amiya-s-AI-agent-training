# %%
import torch
print(torch.__version__)
print(torch.cuda.is_available())
print(torch.cuda.get_device_name(0))
# Out:
# 2.14.0+cu126
# True
# NVIDIA GeForce RTX 4070 SUPER

# %%
import tarfile
with tarfile.open('../data/cifar-10-python.tar.gz', 'r:gz') as t:
    t.extractall('../data')
print("解压完成")
# Out:
# 解压完成
