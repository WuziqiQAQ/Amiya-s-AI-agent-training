# %%
# %pip install transformers -i https://pypi.tuna.tsinghua.edu.cn/simple
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# ...
#      ---------------------------------------- 0.0/12.3 MB ? eta -:--:--
#      ----------------------------------- --- 11.3/12.3 MB 64.0 MB/s eta 0:00:01
#      ---------------------------------------- 12.3/12.3 MB 59.3 MB/s  0:00:00
# ...
#      ---------------------------------------- 0.0/842.9 kB ? eta -:--:--
#      ---------------------------------------- 842.9/842.9 kB 36.3 MB/s  0:00:00
# ...
#      ---------------------------------------- 0.0/2.9 MB ? eta -:--:--
#      ---------------------------------------- 2.9/2.9 MB 173.4 MB/s  0:00:00
# ...
#      ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#      ---------------------------------------- 4.0/4.0 MB 80.2 MB/s  0:00:00
# ...
#
#    ----------------------------------------  0/14 [tqdm]
#    -------- -------------------------------  3/14 [regex]
#    ----------------- ----------------------  6/14 [click]
# ...
